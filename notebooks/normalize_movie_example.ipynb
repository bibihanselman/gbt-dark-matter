# %%
import numpy as np
import os
os.chdir('/home/bhanselman/bhanselman/scripts')
from movies import NormalizedSpectrum

# %%
data_dir = '/home/dataadmin/GBTData/SharedDataDirectory/xband_072625/modified_asymmetry_test_new_formula/injected'
spectra = os.listdir(data_dir)
name = spectra[0]
path = os.path.join(data_dir, name)
norm = NormalizedSpectrum(
    path,
    freq=9450,
    width=100,
    exterior=8,
    order=5,
    a=1,
    mode='weighted'
)
save_dir = '/home/bhanselman/bhanselman/movies/9450_inj_aas.gif'
norm.generate_movie(save_dir=save_dir)
# Out:
# Normalizing spectrum...
# Normalization complete!
# Writing gif...
# MovieWriter ffmpeg unavailable; using Pillow instead.
# gif saved!

# %%
norm.get_norm_spectrum()
# Out:
# array([[9.38607931e+03, 9.38626242e+03, 9.38644552e+03, ...,
#         9.51260519e+03, 9.51278830e+03, 9.51297140e+03],
#        [9.99770433e-01, 9.99778584e-01, 9.99771313e-01, ...,
#         1.00071558e+00, 1.00072407e+00, 1.00073029e+00]])
