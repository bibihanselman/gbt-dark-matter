# %%
import numpy as np
import pandas as pd
import os
os.chdir('/home/bhanselman/gbt_mias/ronit')
from spectra import *

# %%
data_dir = "/home/dataadmin/GBTData/SharedDataDirectory/xband_062525/rebinned_spectra/"
spectra = os.listdir(data_dir)

# %%
spectrum = Spectrum(data_dir + spectra[0])
spectrum.plot()

# %%
spectrum.basic_pfb('rebinned_comb.npy')
spectrum.plot()

# %%
spectrum.num_unit_cells()
# Out:
# 1280

# %%
spectrum.freq, spectrum.power
# Out:
# (array([ 7501.55639648,  7501.73950195,  7501.92260742, ...,
#         11251.00708008, 11251.19018555, 11251.37329102]),
#  array([8909908.06249097, 8331049.20545187, 8203010.11326808, ...,
#         7366187.3401235 , 7422980.96641388, 7709407.58579513]))

# %%
spectrum.cell_size
# Out:
# 16

# %%
import matplotlib.pyplot as plt
plt.plot(spectrum.freq, spectrum.power)
plt.xlim(8500,8510)
plt.ylim(1,1e10)
plt.savefig('combed.png')

# %%
original = Spectrum(data_dir + spectra[0])
plt.plot(original.freq, original.power)
plt.xlim(8500,8510)
plt.ylim(1,1e10)
plt.savefig('uncombed.png')

# %%
import gc
from tqdm.notebook import tqdm
from multiprocessing import Pool

combed_dir = '/home/dataadmin/GBTData/SharedDataDirectory/xband_062525/combed/'
# The loop
def comb(loc):
    spectrum = Spectrum(data_dir + loc)
    spectrum.basic_pfb('rebinned_comb.npy')
    combed = np.array(spectrum.freq, spectrum.power)
    np.save(combed_dir + loc, combed)
    del spectrum
    gc.collect()

with Pool(maxtasksperchild=10) as p:
    result = list(tqdm(p.imap_unordered(comb, spectra), total=len(spectra)))
# Out:
#   0%|          | 0/3230 [00:00<?, ?it/s]

# %% [markdown]
# # Grouping objects together

# %%
groups = {}
for loc in spectra:
    source = loc.split('_')[-2]
    if source not in groups:
        groups[source] = []
    groups[source].append(loc)
len(groups)
# Out:
# 1924

# %%
df = pd.read_csv('/home/dataadmin/GBTData/SharedDataDirectory/xband_062525/xband_info.csv')
df = df[df['source'] == 'HIP32010']
df
# Out:
#         source          mjd  \
# 1     HIP32010  58493.28442
# 43    HIP32010  58493.29908
# 49    HIP32010  58493.29123
# 1979  HIP32010  58417.40392
# 1983  HIP32010  58417.41090
# 1987  HIP32010  58417.41775
#
#                                                filename           l         b  \
# 1     spliced_blc00010203040506o7o0111213141516o7o02...  190.344555  8.571999
# 43    spliced_blc00010203040506o7o0111213141516o7o02...  190.340897  8.572337
# 49    spliced_blc00010203040506o7o0111213141516o7o02...  190.339927  8.573108
# 1979  spliced_blc00010203040506o7o0111213141516o7o02...  190.341968  8.572228
# 1983  spliced_blc00010203040506o7o0111213141516o7o02...  190.340695  8.572841
# 1987  spliced_blc00010203040506o7o0111213141516o7o02...  190.340544  8.572304
#
#            theta         phi           nfw        nfw_sq           iso  \
# 1     100.227749  166.595237  1.002481e+08  5.013778e+14  2.526118e+08
# 43    100.224124  166.597825  1.002477e+08  5.013747e+14  2.526113e+08
# 49    100.223145  166.598080  1.002476e+08  5.013744e+14  2.526112e+08
# 1979  100.225186  166.597074  1.002478e+08  5.013756e+14  2.526114e+08
# 1983  100.223911  166.597661  1.002477e+08  5.013749e+14  2.526113e+08
# 1987  100.223776  166.598117  1.002476e+08  5.013743e+14  2.526112e+08
#
#             iso_sq       burkert    burkert_sq         moore      moore_sq
# 1     1.146479e+15  8.582130e+07  4.093387e+14  2.187004e+07  2.896061e+13
# 43    1.146474e+15  8.582095e+07  4.093362e+14  2.186994e+07  2.896042e+13
# 49    1.146474e+15  8.582091e+07  4.093359e+14  2.186994e+07  2.896040e+13
# 1979  1.146476e+15  8.582105e+07  4.093369e+14  2.186997e+07  2.896047e+13
# 1983  1.146474e+15  8.582097e+07  4.093363e+14  2.186995e+07  2.896043e+13
# 1987  1.146474e+15  8.582091e+07  4.093359e+14  2.186993e+07  2.896040e+13

# %%
spectra = np.array([np.load(data_dir + loc) for loc in groups['HIP32010']])
xs = spectra[0,0]
ys = np.mean(spectra[:,1], axis=0)
np.array([xs,ys])
# Out:
# array([[7.50155640e+03, 7.50173950e+03, 7.50192261e+03, ...,
#         1.12510071e+04, 1.12511902e+04, 1.12513733e+04],
#        [5.29141250e+06, 7.40515358e+06, 8.17265175e+06, ...,
#         7.34977733e+06, 6.58320558e+06, 4.55673567e+06]])

# %%
from astropy.coordinates import SkyCoord
def get_theta_phi(l, b):
    gal = SkyCoord(l, b, unit='deg', frame='galactic')
    v_sun = SkyCoord(90, 0, unit='deg', frame='galactic')
    v_gc = SkyCoord(0, 0, unit='deg', frame='galactic')
    theta = v_sun.separation(gal).deg
    phi = v_gc.separation(gal).deg
    return theta, phi

# %%
grouped_dir = "/home/dataadmin/GBTData/SharedDataDirectory/xband_062525/rebinned_spectra_g/"

info = pd.read_csv('/home/dataadmin/GBTData/SharedDataDirectory/xband_062525/xband_info.csv')

#for source, locs in tqdm(groups.items()):
def group(source, locs):
    spectra = np.array([np.load(data_dir + loc) for loc in locs])
    xs = spectra[0,0]
    ys = np.mean(spectra[:,1], axis=0)
    np.save(grouped_dir + source, np.array([xs,ys]))
    del spectra
    gc.collect()
    # Update csv
    filt = info[info['source'] == source]
    ls, bs = filt['l'].to_numpy(), filt['b'].to_numpy()
    l, b = np.mean(ls), np.mean(bs)
    theta, phi = get_theta_phi(l, b)
    return source, l, b, theta, phi
    
with Pool(maxtasksperchild=10) as p:
    data = list(tqdm(p.imap_unordered(group, groups.items()), total=len(groups)))
    
columns = ['source', 'l', 'b', 'theta', 'phi']
df = pd.DataFrame(data, columns=columns)
df.to_csv('/home/dataadmin/GBTData/SharedDataDirectory/xband_062525/xband_info_g.csv', index=False)
