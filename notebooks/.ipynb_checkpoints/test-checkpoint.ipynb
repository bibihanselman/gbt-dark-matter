# %%
import os
os.chdir('../home/dataadmin')
os.listdir()
# Out:
# ['.bash_logout',
#  '.bash_profile',
#  '.emacs',
#  '.ssh',
#  '.bash_history',
#  'GBTData',
#  '.python_history',
#  'history.txt',
#  'history_colossus.txt',
#  '.bashrc',
#  '.viminfo']
